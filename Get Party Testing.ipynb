# %%
from getPARTY import *

# %%
# %matplotlib inline
import seaborn as sns

# %%
df_merged = merge_contrib_pid("2012", "Boeing")
sns.countplot(x="party_id", data=df_merged, palette="Greens_d");

# %%
getPARTY("2012__Amazon__schedule_a_merged.csv")
# Out:
# [*] finding party id's for requested committees...
# [*] conducting schedule b search...
# [*] conducting schedule b search...
# [*] conducting schedule b search...
# [*] conducting schedule b search...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] conducting schedule b search...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] conducting schedule b search...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] candidate id exists but no party results
# ...

# %%
df_merged = merge_contrib_pid("2012", "Amazon")
sns.countplot(x="party_id", data=df_merged, palette="Greens_d");

# %%
getPARTY("2012__General_Electric__schedule_a_merged.csv")
# Out:
# [*] finding party id's for requested committees...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] conducting schedule b search...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] conducting schedule b search...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] conducting schedule b search...
# [*] party id found in committee details:
# ...

# %%
df_merged = merge_contrib_pid("2012", "General_Electric")
sns.countplot(x="party_id", data=df_merged, palette="Greens_d");

# %%
getPARTY("2012__Exxon_Mobile__schedule_a_merged.csv")
# Out:
# [*] finding party id's for requested committees...
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] candidate id exists but no party results
# [*] party id found in committee details:
# [*] party id found in committee details:
# [*] party id found in committee details:
# ...

# %%
df_merged = merge_contrib_pid("2012", "Exxon_Mobile")
sns.countplot(x="party_id", data=df_merged, palette="Greens_d");
